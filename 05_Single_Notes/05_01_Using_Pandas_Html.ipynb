# %%
import pandas as pd
import pickle
from string import ascii_uppercase as alphabet

# %%
# extracting all tables in website, basically extract all the table class (work in a similar way as bs4)
all_tables = pd.read_html('https://en.wikipedia.org/wiki/2022_FIFA_World_Cup')

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
print(all_tables[2])
# Out:
#                             Place Amount (in millions)
#                             Place             Per team Total
# 0                       Champions                  $42   $42
# 1                      Runners-up                  $30   $30
# 2                     Third place                  $27   $27
# 3                    Fourth place                  $25   $25
# 4  5th–8th place (quarter-finals)                  $17   $68
# 5    9th–16th place (Round of 16)                  $13  $104
# 6   17th–32nd place (Group stage)                   $9  $144
# 7                           Total                Total  $440

# %%
print(type(all_tables[2]))
# Out:
# <class 'pandas.core.frame.DataFrame'>

# %%
print(all_tables[2].columns)
# Out:
# MultiIndex([(               'Place',    'Place'),
#             ('Amount (in millions)', 'Per team'),
#             ('Amount (in millions)',    'Total')],
#            )
